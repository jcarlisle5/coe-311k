# %%
## implement a function that will take a matrix as a 
## parameter and returns True or False depending if 
## the matrix is Diagonally Dominant or not.

import numpy as np

## A is not diagonally dominant.
A = np.array([[4, 1, 7, 2, 4],
             [2, 2, 2, 2, 2],
              [1, 3, 5, 8, 9],
              [1, 2, 2, 2, 2],
              [0, 1, 0, 0, 0]])

## B is diagonally dominant.
B = np.array([[5, 0, 3], 
              [2, 7, 0], 
              [1, 1, 9]])
print(A[0])
print(A[0][0])

## Check all rows

def is_diag_dom(A)
    size = len(A)
    for i in range(0, len(A)):
# Out:
# [4 1 7 2 4]
# 4
# 10

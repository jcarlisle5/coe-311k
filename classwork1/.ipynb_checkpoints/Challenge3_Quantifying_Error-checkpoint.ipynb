# %%
# Monte carlo python

import random # Here is my montecarlo math. I used the distance formula to quickly solve this one.
import math
import numpy

def montecarlopi(numpoints):
    inside_circle = 0
    for i in range(numpoints):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        if math.sqrt((x**2 + y**2)) <= 1:
            inside_circle +=1

    return 4 * inside_circle / numpoints

result = montecarlopi(1000)
print(result)
# Out:
# 3.12

# %%
import numpy as np # This is the code segement that calculates then adds to error lists in a for loop.
import math
true_error_list = []
abs_error_list = []
n = 10
for i in range(1, 101):
    result = montecarlopi(n)
    true_error = abs(np.pi - result)
    relative_error = abs((np.pi - result) / np.pi)
    true_error_list.append(f"{true_error:.15}")
    abs_error_list.append(f"{relative_error:.15}")
    n += 20

# %%
import matplotlib.pyplot as plt ## Here is the plotting routine, I plotted the error and the # of trials.
plt.plot(true_error_list, abs_error_list)
plt.show()
